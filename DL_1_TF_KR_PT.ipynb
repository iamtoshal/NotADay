# %%
##TENSORFLOW

# %%
import tensorflow as tf
import numpy as np

# %%
a = tf.constant([[1,3],
                [2,4]])
b = tf.constant([[1,1],
                [2,2]])

# %%
print(a+b)
# Out:
# tf.Tensor(
# [[2 4]
#  [4 6]], shape=(2, 2), dtype=int32)

# %%
x = np.random.rand(100).astype(np.float32)
print(x)
# Out:
# [0.9511424  0.6716715  0.46364066 0.51816875 0.5231936  0.31079033
#  0.79599583 0.20089975 0.3288255  0.91914743 0.65311855 0.33584005
#  0.31085727 0.61967164 0.6639311  0.98187274 0.10661719 0.96592945
#  0.5627306  0.4407569  0.85769415 0.2839393  0.01241841 0.91036266
#  0.6545728  0.00255433 0.67514026 0.84835523 0.5079594  0.779866
#  0.8927157  0.44742498 0.19351995 0.9010664  0.5236787  0.31202963
#  0.4242046  0.2740743  0.25660667 0.23209159 0.5485522  0.4324749
#  0.91290367 0.31219262 0.8249075  0.44079897 0.62256587 0.2685203
#  0.13385305 0.19119361 0.41266456 0.2965987  0.65892196 0.69477206
#  0.34241843 0.6376019  0.50726587 0.5769622  0.00291623 0.14870653
#  0.4415439  0.02774359 0.49920368 0.2887906  0.5838207  0.51246107
#  0.9819332  0.17887723 0.6815182  0.68112224 0.96316314 0.10740443
#  0.26265085 0.39006793 0.3226052  0.5385419  0.14844078 0.43531644
#  0.76240844 0.5910943  0.08721524 0.60043913 0.1865538  0.0669349
# ...

# %%
y = x*0.2+0.2
w = tf.Variable(tf.random.normal([1]))
b = tf.Variable(tf.random.normal([1]))

# %%
def mse_loss():
    y_pred = w*x+b
    loss = tf.reduce_mean(tf.square(y_pred-y))
    return loss

# %%
optimizer = tf.keras.optimizers.Adam()

# %%
for step in range(5000):
    optimizer.minimize(mse_loss,var_list=[w,b])
    if step%500 == 0:
        print(step,w.numpy(),b.numpy())
# Out:
# 0 [-0.70213014] [0.7751984]
# 500 [-0.14732446] [0.40566307]
# 1000 [0.12366103] [0.24487804]
# 1500 [0.19191621] [0.20475057]
# 2000 [0.19965617] [0.20020206]
# 2500 [0.19999534] [0.20000273]
# 3000 [0.19999912] [0.20000052]
# 3500 [0.19999935] [0.2000004]
# 4000 [0.19999948] [0.20000032]
# 4500 [0.19999963] [0.20000023]

# %%
##KERAS

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd

# %%
df = pd.read_csv("D:\Deep Learning\Deep Learning - Datasets\diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
y = df['Outcome']
x = df.drop(labels=['Outcome'],axis=1)

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
model = Sequential([
    Dense(12,input_shape=(8,),activation='relu'),
    Dense(8,activation='relu'),
    Dense(1,activation='softmax'),
])

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
H = model.fit(x,y,batch_size=16,epochs=200)
# Out:
# Epoch 1/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.5414 - accuracy: 0.3490
# Epoch 2/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.5359 - accuracy: 0.3490
# Epoch 3/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.5270 - accuracy: 0.3490
# Epoch 4/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.5356 - accuracy: 0.3490
# Epoch 5/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.5306 - accuracy: 0.3490
# Epoch 6/200
# 48/48 [==============================] - 0s 3ms/step - loss: 0.5260 - accuracy: 0.3490
# Epoch 7/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.5326 - accuracy: 0.3490
# Epoch 8/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.5254 - accuracy: 0.3490
# Epoch 9/200
# 48/48 [==============================] - 0s 2ms/step - loss: 0.5297 - accuracy: 0.3490
# Epoch 10/200
# ...

# %%
model.evaluate(x,y)
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4720 - accuracy: 0.3490
# [0.4719836711883545, 0.3489583432674408]

# %%
##PYTORCH

# %%
# !pip install torch
# Out:
# ...
#      -------------------------------------- 192.2/192.2 MB 1.9 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.3; however, version 23.3.1 is available.
# You should consider upgrading via the 'C:\Users\Hp\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import torch
import numpy as np

# %%
data = [[1,2],[2,3]]

# %%
print(type(data))
tensor_data = torch.tensor(data)
print(type(tensor_data))
# Out:
# <class 'list'>
# <class 'torch.Tensor'>

# %%
#using numpy
np_data = np.array(data)
print(type(np_data))
tes_data = torch.tensor(np_data)
print(type(tes_data))
# Out:
# <class 'numpy.ndarray'>
# <class 'torch.Tensor'>

# %%
new_tensor = torch.ones_like(tensor_data)
print(type(new_tensor))
print(new_tensor)
# Out:
# <class 'torch.Tensor'>
# tensor([[1, 1],
#         [1, 1]])

# %%
shape = (2,3)
random_tensor = torch.rand(shape)
print(random_tensor)
# Out:
# tensor([[0.2960, 0.4282, 0.6730],
#         [0.8847, 0.4188, 0.6041]])

# %%
tensor_1 = torch.ones(2,3)
tensor_2 = torch.zeros(2,3)
print(tensor_1)
print(tensor_2)
tens=tensor_1.add(4)
print(tens)
tens_1=tensor_2.add(tens)
print(tens_1)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])
# tensor([[5., 5., 5.],
#         [5., 5., 5.]])
# tensor([[5., 5., 5.],
#         [5., 5., 5.]])
